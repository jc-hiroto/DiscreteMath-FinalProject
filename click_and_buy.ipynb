# %%
import pandas as pd
import numpy as np
buys = pd.read_csv("buys_by_item.csv")
clicks = pd.read_csv("clicks_by_item.csv")

# %%
res = pd.concat([buys,clicks],axis=1)
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52739 entries, 0 to 52738
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item_id   19949 non-null  float64
#  1   price     19949 non-null  float64
#  2   quantity  19949 non-null  float64
#  3   item_id   52739 non-null  int64
#  4   clicks    52739 non-null  int64
# dtypes: float64(3), int64(2)
# memory usage: 2.0 MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52739 entries, 0 to 52738
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item_id   19949 non-null  float64
#  1   price     19949 non-null  float64
#  2   quantity  19949 non-null  float64
#  3   item      52739 non-null  int64
#  4    clicks   52739 non-null  int64
# dtypes: float64(3), int64(2)
# memory usage: 2.0 MB
