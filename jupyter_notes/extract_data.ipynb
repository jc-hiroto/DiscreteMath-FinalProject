# %%
from ipynb.fs.full.functions import extractTrainData,extractSession
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-521e2cc4c34d> in <module>
# ----> 1 from ipynb.fs.full.functions import extractTrainData,extractSession
#
# ~\Documents\b07505032-FinalProject\functions.ipynb in <module>
#     140   },
#     141   {
# --> 142    "cell_type": "code",
#     143    "execution_count": null,
#     144    "metadata": {},
#
# ~\Documents\b07505032-FinalProject\functions.ipynb in getPurchaseDataA(length)
#      53     "          \" sec.  |  Last click until buy: \"+str((time - clickTime[-1]).total_seconds())+\" sec.\",end=\"\\n\\n\")\n",
#      54     "\n",
# ---> 55     "# iterate through all buy sessions.\n",
#      56     "def getPurchaseDataA(length=-1):\n",
#      57     "    loop = 0\n",
#
# c:\python39\lib\site-packages\pandas\core\frame.py in iterrows(self)
#    1011         columns = self.columns
# ...

# %%
# Extract given session data. (for trainning)
# Trainning dataset Ver.1
resL=[]
for i in range(15,64):
    print("============================= PARTITION "+str(i)+" START =============================")
    filep = PATH+str(i)+".csv"
    dfp = pd.read_csv(filep,parse_dates = [1], date_parser = dateparse)
    sg = dfp.groupby('session')
    for id, group in sg:
        resL.extend(extractSession(id,group))
    print("============================= PARTITION "+str(i)+" DONE =============================")
df = pd.DataFrame(resL)    
df.info()
df = df.sort_values(by='session',ascending=True)
df.head(100)
df.to_csv('old_train_data/session_buy_data_15_64.csv',index=False)

# %%
# Extract test session data
# Testing dataset Ver.1
resT=[]
test = pd.read_csv("yoochoose-data/yoochoose-test.dat",parse_dates = [1], date_parser = dateparse,nrows=100000)
sg = test.groupby('session')
for id, group in sg:
    resT.extend(extractSession(id,group,True))
dfresT = pd.DataFrame(resT)    
dfresT.info()
dfresT.to_csv('test_data_100k.csv',index=False)

# %%
# Extract given session data. (for trainning)
# Trainning dataset Ver.2
for i in range(20,30):
    rpath = "parts/clicks_p"+str(i)+".csv"
    wpath = "train_data/train_data_p"+str(i)+".csv"
    print("Read from",rpath)
    print("Write to",wpath)
    r = []
    df = pd.read_csv(rpath,parse_dates = [1], date_parser = dateparse)
    sg = df.groupby('session')
    for id, group in sg:
        r.extend(extractTrainData(id,group,False))
    train = pd.DataFrame(r)
    print(train)
    train.to_csv(wpath,index=False)
